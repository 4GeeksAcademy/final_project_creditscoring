# %%
import os

# %% [markdown]
# # 1️⃣ Install and configure the Kaggle API
#
# Install the Kaggle library if you don't already have it:

# %%
pip install kaggle
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Obtaining the credentials:
#
# - Go to Kaggle and log in to your account.
#
# - Click on your profile → Account → API section → Create New API Token button.
#
# - A kaggle.json file will be downloaded.

# %% [markdown]
# ## Move kaggle.json to the correct folder:
#
# In this case, we're moving it to the Data folder.

# %%
# Indicamos a Kaggle dónde está el kaggle.json
os.environ["KAGGLE_CONFIG_DIR"] = os.path.join(os.getcwd(), "../Data")

# %% [markdown]
# # 2️⃣ We identified the LendingClub dataset
#
# The file you're looking for is in the Kaggle dataset:
#
# - URL: https://www.kaggle.com/datasets/wordsforthewise/lending-club/data
#
# - Dataset: LendingClub Loan Data
#
# - File: accepted_2007_to_2018Q4.csv.gz

# %% [markdown]
# # 3️⃣ Download the CSV using the API

# %%
# !kaggle datasets download \
  -d wordsforthewise/lending-club \
  -f accepted_2007_to_2018Q4.csv.gz \
  -p /workspaces/final_project_creditscoring/Data \
  --force
# Out:
# Dataset URL: https://www.kaggle.com/datasets/wordsforthewise/lending-club
# License(s): CC0-1.0
# ...
#  99%|███████████████████████████████████████▋| 371M/374M [00:13<00:00, 37.7MB/s]
# 100%|████████████████████████████████████████| 374M/374M [00:14<00:00, 27.9MB/s]

# %% [markdown]
# # 4️⃣ We decompress the csv.gz

# %%
# !gunzip -k /workspaces/final_project_creditscoring/Data/accepted_2007_to_2018Q4.csv.gz
