# %%
import os

# %% [markdown]
# # 1️⃣ Instalar y configurar la API de Kaggle
#
# Instala la librería de Kaggle si no la tienes aún:

# %%
pip install kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-1.8.3-py3-none-any.whl.metadata (16 kB)
# Collecting black>=24.10.0 (from kaggle)
#   Downloading black-26.1.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (88 kB)
# Requirement already satisfied: bleach in /home/codespace/.local/lib/python3.12/site-packages (from kaggle) (6.3.0)
# Collecting kagglesdk<1.0,>=0.1.14 (from kaggle)
#   Downloading kagglesdk-0.1.15-py3-none-any.whl.metadata (13 kB)
# Collecting mypy>=1.15.0 (from kaggle)
#   Downloading mypy-1.19.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.2 kB)
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.12/site-packages (from kaggle) (25.0)
# Collecting protobuf (from kaggle)
#   Downloading protobuf-6.33.4-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Requirement already satisfied: python-dateutil in /home/codespace/.local/lib/python3.12/site-packages (from kaggle) (2.9.0.post0)
# Collecting python-slugify (from kaggle)
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.12/site-packages (from kaggle) (2.32.5)
# Requirement already satisfied: six>=1.10 in /home/codespace/.local/lib/python3.12/site-packages (from kaggle) (1.17.0)
# Collecting tqdm (from kaggle)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting types-requests (from kaggle)
#   Downloading types_requests-2.32.4.20260107-py3-none-any.whl.metadata (2.0 kB)
# Collecting types-tqdm (from kaggle)
#   Downloading types_tqdm-4.67.0.20250809-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: urllib3>=1.15.1 in /home/codespace/.local/lib/python3.12/site-packages (from kaggle) (2.5.0)
# Collecting click>=8.0.0 (from black>=24.10.0->kaggle)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting mypy-extensions>=0.4.3 (from black>=24.10.0->kaggle)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting pathspec>=1.0.0 (from black>=24.10.0->kaggle)
#   Downloading pathspec-1.0.3-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs>=2 in /home/codespace/.local/lib/python3.12/site-packages (from black>=24.10.0->kaggle) (4.5.0)
# Collecting pytokens>=0.3.0 (from black>=24.10.0->kaggle)
#   Downloading pytokens-0.4.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: typing_extensions>=4.6.0 in /home/codespace/.local/lib/python3.12/site-packages (from mypy>=1.15.0->kaggle) (4.15.0)
# Collecting librt>=0.6.2 (from mypy>=1.15.0->kaggle)
#   Downloading librt-0.7.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: webencodings in /home/codespace/.local/lib/python3.12/site-packages (from bleach->kaggle) (0.5.1)
# Collecting text-unidecode>=1.3 (from python-slugify->kaggle)
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests->kaggle) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests->kaggle) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests->kaggle) (2025.11.12)
# Downloading kaggle-1.8.3-py3-none-any.whl (102 kB)
# Downloading kagglesdk-0.1.15-py3-none-any.whl (160 kB)
# Downloading black-26.1.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 48.7 MB/s  0:00:00
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading mypy-1.19.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (13.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 51.2 MB/s  0:00:006m0:00:01
# Downloading librt-0.7.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (192 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading pathspec-1.0.3-py3-none-any.whl (55 kB)
# Downloading pytokens-0.4.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (268 kB)
# Downloading protobuf-6.33.4-cp39-abi3-manylinux2014_x86_64.whl (323 kB)
# Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading types_requests-2.32.4.20260107-py3-none-any.whl (20 kB)
# Downloading types_tqdm-4.67.0.20250809-py3-none-any.whl (24 kB)
# Installing collected packages: text-unidecode, types-requests, tqdm, pytokens, python-slugify, protobuf, pathspec, mypy-extensions, librt, click, types-tqdm, mypy, kagglesdk, black, kaggle
#   WARNING: The script tqdm is installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script slugify is installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━ 11/15 [mypy]  WARNING: The scripts dmypy, mypy, mypyc, stubgen and stubtest are installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━ 13/15 [black]sdk]  WARNING: The scripts black and blackd are installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script kaggle is installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15/15 [kaggle]
# Successfully installed black-26.1.0 click-8.3.1 kaggle-1.8.3 kagglesdk-0.1.15 librt-0.7.8 mypy-1.19.1 mypy-extensions-1.1.0 pathspec-1.0.3 protobuf-6.33.4 python-slugify-8.0.4 pytokens-0.4.0 text-unidecode-1.3 tqdm-4.67.1 types-requests-2.32.4.20260107 types-tqdm-4.67.0.20250809
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Obtener las credenciales:
#
# - Ve a Kaggle, entra a tu cuenta.
#
# - Haz clic en tu perfil → Account → sección API → botón Create New API Token.
#
# - Se descargará un archivo kaggle.json

# %% [markdown]
# ## Mover kaggle.json a la carpeta correcta:
#
# En este caso la cargamos a la carpeta Data

# %%
# Indicamos a Kaggle dónde está el kaggle.json
os.environ["KAGGLE_CONFIG_DIR"] = os.path.join(os.getcwd(), "../Data")

# %% [markdown]
# # 2️⃣ Identificamos el dataset de LendingClub
#
# El archivo que buscas está en el dataset de Kaggle:
#
# - url: https://www.kaggle.com/datasets/wordsforthewise/lending-club/data
#
# - Dataset: LendingClub Loan Data
#
# - Archivo: accepted_2007_to_2018Q4.csv.gz

# %% [markdown]
# # 3️⃣ Descargar el CSV con la API

# %%
# !kaggle datasets download \
  -d wordsforthewise/lending-club \
  -f accepted_2007_to_2018Q4.csv.gz \
  -p /workspaces/final_project_creditscoring/Data \
  --force
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /workspaces/final_project_creditscoring/notebooks/../Data/kaggle.json'
# Dataset URL: https://www.kaggle.com/datasets/wordsforthewise/lending-club
# License(s): CC0-1.0
# Downloading accepted_2007_to_2018Q4.csv.gz to /workspaces/final_project_creditscoring/Data
#  99%|███████████████████████████████████████▌| 370M/374M [00:09<00:00, 42.7MB/s]
# 100%|████████████████████████████████████████| 374M/374M [00:09<00:00, 40.8MB/s]

# %% [markdown]
# # 4️⃣ Descomprimimos el csv.gz

# %%
# !gunzip -k /workspaces/final_project_creditscoring/Data/accepted_2007_to_2018Q4.csv.gz
